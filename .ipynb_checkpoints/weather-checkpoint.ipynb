# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from citipy import citipy
import json
import time; time.time()

# Range of latitudes and longitudes
lat_range = (64, 20)
lng_range = (-154, -65)

# Output File (CSV)
output_data_file = "data/cities.csv"

# Import API key
from api_keys import weather_key

# %%
weather_data_df = pd.read_csv("data/tornadoes.csv")
weather_data_df.head()
# Out:
#    EVENT_ID     CZ_NAME_STR  BEGIN_LOCATION  BEGIN_DATE  BEGIN_TIME  \
# 0    866322    CARTERET CO.  TRUTTNEYS LNDG   11/1/2019          15
# 1    859389      MARTIN CO.        WAVELAND   11/5/2019        1620
# 2    864077      MOBILE CO.        PRICHARD   11/7/2019        1335
# 3    857862   FRANKLIN PAR.          BASKIN  11/26/2019        1803
# 4    857944  CLAIBORNE PAR.           MAHAN  11/26/2019        1820
#
#   EVENT_TYPE MAGNITUDE TOR_F_SCALE  DEATHS_DIRECT  INJURIES_DIRECT  ...  \
# 0    Tornado                   EF0              0                0  ...
# 1    Tornado                   EF0              0                0  ...
# 2    Tornado                   EF0              0                0  ...
# 3    Tornado                   EF2              1                1  ...
# 4    Tornado                   EF1              0                0  ...
#
#    END_RANGE  END_AZIMUTH    END_LOCATION BEGIN_LAT BEGIN_LON  END_LAT  \
# 0          1          NNW  TRUTTNEYS LNDG   34.7394  -77.1094  34.7411
# 1          2          ENE        WAVELAND   27.2140  -80.1729  27.2123
# 2          0          SSE        PRICHARD   30.7248  -88.0548  30.7260
# 3          4           NE          BASKIN   32.2351  -91.7783  32.3184
# 4          2          NNE           MAHAN   32.9017  -93.0423  32.9076
#
#    END_LON                                    EVENT_NARRATIVE  \
# 0 -77.1053  A brief tornado occurred near the intersection...
# 1 -80.1766  Martin County Beach Patrol reported a waterspo...
# 2 -88.0486  The storm survey team surveyed the areas aroun...
# 3 -91.7095  This tornado began on Roger Miller Road as it ...
# 4 -93.0343  An EF-1 tornado with estimated maximum winds a...
#
#                                    EPISODE_NARRATIVE  ABSOLUTE_ROWNUMBER
# 0  A strong cold front moved across Eastern North...                   1
# 1  A strong thunderstorm produced a waterspout ju...                   2
# 2  Thunderstorms moved across the area during the...                   3
# 3  Warm, moist air was in place across northeast ...                   4
# 4  A deep southwesterly flow aloft ahead of a lar...                   5
#
# [5 rows x 37 columns]

# %%
tornado_df = weather_data_df.loc[:,["BEGIN_LOCATION", "STATE_ABBR", "BEGIN_DATE", "EVENT_TYPE", "TOR_F_SCALE", "DEATHS_DIRECT", "BEGIN_LAT", "BEGIN_LON", "END_LOCATION"]]
tornado_df.head()
# Out:
#    BEGIN_LOCATION STATE_ABBR  BEGIN_DATE EVENT_TYPE TOR_F_SCALE  \
# 0  TRUTTNEYS LNDG         NC   11/1/2019    Tornado         EF0
# 1        WAVELAND         FL   11/5/2019    Tornado         EF0
# 2        PRICHARD         AL   11/7/2019    Tornado         EF0
# 3          BASKIN         LA  11/26/2019    Tornado         EF2
# 4           MAHAN         LA  11/26/2019    Tornado         EF1
#
#    DEATHS_DIRECT  BEGIN_LAT  BEGIN_LON    END_LOCATION
# 0              0    34.7394   -77.1094  TRUTTNEYS LNDG
# 1              0    27.2140   -80.1729        WAVELAND
# 2              0    30.7248   -88.0548        PRICHARD
# 3              1    32.2351   -91.7783          BASKIN
# 4              0    32.9017   -93.0423           MAHAN

# %%
gmaps.configure(api_key = weather_key)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 546

# %%
for index, row in tornado_df.iterrows():
    base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=04c41275fea3e8291170fd88095dde0f"
    beg_lat= row['BEGIN_LAT']
    beg_lon= row['BEGIN_LON']

# %%
tornado_df = tornado_df.rename(columns={"BEGIN_LOCATION": "City", "BEGIN_LAT":"Lat", "BEGIN_LON":"Lng", "BEGIN_DATE": "Date"})
tornado_df.head()
# Out:
#              City STATE_ABBR        Date EVENT_TYPE TOR_F_SCALE  \
# 0  TRUTTNEYS LNDG         NC   11/1/2019    Tornado         EF0
# 1        WAVELAND         FL   11/5/2019    Tornado         EF0
# 2        PRICHARD         AL   11/7/2019    Tornado         EF0
# 3          BASKIN         LA  11/26/2019    Tornado         EF2
# 4           MAHAN         LA  11/26/2019    Tornado         EF1
#
#    DEATHS_DIRECT      Lat      Lng    END_LOCATION
# 0              0  34.7394 -77.1094  TRUTTNEYS LNDG
# 1              0  27.2140 -80.1729        WAVELAND
# 2              0  30.7248 -88.0548        PRICHARD
# 3              1  32.2351 -91.7783          BASKIN
# 4              0  32.9017 -93.0423           MAHAN

# %%
cities_lat_lng = requests.get(base_url)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=04c41275fea3e8291170fd88095dde0f"
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for x, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (x % 50 == 0 and x >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | craig
# Processing Record 3 of Set 1 | coos bay
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | timmins
# Processing Record 6 of Set 1 | palmer
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | hay river
# Processing Record 10 of Set 1 | college
# Processing Record 11 of Set 1 | fortuna
# Processing Record 12 of Set 1 | todos santos
# Processing Record 13 of Set 1 | jaguey grande
# Processing Record 14 of Set 1 | iroquois falls
# Processing Record 15 of Set 1 | la ronge
# Processing Record 16 of Set 1 | naica
# Processing Record 17 of Set 1 | kahului
# Processing Record 18 of Set 1 | nantucket
# Processing Record 19 of Set 1 | piney green
# Processing Record 20 of Set 1 | thessalon
# Processing Record 21 of Set 1 | nipawin
# Processing Record 22 of Set 1 | flin flon
# Processing Record 23 of Set 1 | cockburn town
# Processing Record 24 of Set 1 | laramie
# Processing Record 25 of Set 1 | xilitla
# Processing Record 26 of Set 1 | pacifica
# Processing Record 27 of Set 1 | puerto palomas
# Processing Record 28 of Set 1 | fort nelson
# Processing Record 29 of Set 1 | portales
# Processing Record 30 of Set 1 | port hardy
# Processing Record 31 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 1 | lompoc
# Processing Record 34 of Set 1 | constitucion
# Processing Record 35 of Set 1 | dunn
# Processing Record 36 of Set 1 | kapuskasing
# Processing Record 37 of Set 1 | mastic
# Processing Record 38 of Set 1 | gravelbourg
# Processing Record 39 of Set 1 | guerrero negro
# Processing Record 40 of Set 1 | pacific grove
# Processing Record 41 of Set 1 | irondequoit
# Processing Record 42 of Set 1 | marsh harbour
# Processing Record 43 of Set 1 | hamilton
# Processing Record 44 of Set 1 | dallas
# Processing Record 45 of Set 1 | chapais
# Processing Record 46 of Set 1 | el sauzal
# Processing Record 47 of Set 1 | matagami
# Processing Record 48 of Set 1 | venice
# Processing Record 49 of Set 1 | kirksville
# Processing Record 50 of Set 1 | brownwood
# Processing Record 0 of Set 2 | thompson
# Processing Record 1 of Set 2 | didsbury
# Processing Record 2 of Set 2 | fort frances
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | ascension
# Processing Record 5 of Set 2 | half moon bay
# Processing Record 6 of Set 2 | rutland
# Processing Record 7 of Set 2 | ahumada
# City not found. Skipping...
# Processing Record 8 of Set 2 | jacksonville beach
# Processing Record 9 of Set 2 | smithfield
# Processing Record 10 of Set 2 | rawlins
# Processing Record 11 of Set 2 | high rock
# Processing Record 12 of Set 2 | the pas
# Processing Record 13 of Set 2 | edson
# Processing Record 14 of Set 2 | wasilla
# Processing Record 15 of Set 2 | mantua
# Processing Record 16 of Set 2 | campbell river
# Processing Record 17 of Set 2 | hearst
# Processing Record 18 of Set 2 | santa rosalia
# Processing Record 19 of Set 2 | celestun
# Processing Record 20 of Set 2 | shelburne
# Processing Record 21 of Set 2 | billings
# Processing Record 22 of Set 2 | san quintin
# Processing Record 23 of Set 2 | high prairie
# Processing Record 24 of Set 2 | swift current
# Processing Record 25 of Set 2 | dillon
# Processing Record 26 of Set 2 | carlsbad
# Processing Record 27 of Set 2 | valparaiso
# Processing Record 28 of Set 2 | shasta lake
# Processing Record 29 of Set 2 | elizabeth city
# Processing Record 30 of Set 2 | road town
# Processing Record 31 of Set 2 | fairbanks
# Processing Record 32 of Set 2 | louisville
# Processing Record 33 of Set 2 | mayo
# Processing Record 34 of Set 2 | glens falls
# Processing Record 35 of Set 2 | poquoson
# Processing Record 36 of Set 2 | smithers
# Processing Record 37 of Set 2 | loiza
# Processing Record 38 of Set 2 | saint-andre-avellin
# Processing Record 39 of Set 2 | norfolk
# Processing Record 40 of Set 2 | dickinson
# Processing Record 41 of Set 2 | meredith
# Processing Record 42 of Set 2 | coffeyville
# Processing Record 43 of Set 2 | banff
# Processing Record 44 of Set 2 | grande prairie
# Processing Record 45 of Set 2 | brownfield
# Processing Record 46 of Set 2 | lovington
# Processing Record 47 of Set 2 | high level
# Processing Record 48 of Set 2 | greenfield
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 0 of Set 3 | willmar
# Processing Record 1 of Set 3 | mandan
# Processing Record 2 of Set 3 | selma
# Processing Record 3 of Set 3 | chalchihuites
# Processing Record 4 of Set 3 | eureka
# Processing Record 5 of Set 3 | malartic
# Processing Record 6 of Set 3 | shelton
# Processing Record 7 of Set 3 | sagua de tanamo
# Processing Record 8 of Set 3 | thunder bay
# Processing Record 9 of Set 3 | mazatlan
# Processing Record 10 of Set 3 | lively
# Processing Record 11 of Set 3 | providencia
# Processing Record 12 of Set 3 | terrace
# Processing Record 13 of Set 3 | santa fe
# Processing Record 14 of Set 3 | port-cartier
# Processing Record 15 of Set 3 | bagotville
# Processing Record 16 of Set 3 | henderson
# Processing Record 17 of Set 3 | pemberton
# Processing Record 18 of Set 3 | jaltocan
# Processing Record 19 of Set 3 | geraldton
# Processing Record 20 of Set 3 | san juan
# Processing Record 21 of Set 3 | juneau
# Processing Record 22 of Set 3 | bobcaygeon
# Processing Record 23 of Set 3 | ahuimanu
# Processing Record 24 of Set 3 | loreto
# Processing Record 25 of Set 3 | fort walton beach
# Processing Record 26 of Set 3 | ucluelet
# Processing Record 27 of Set 3 | vernon
# Processing Record 28 of Set 3 | storm lake
# Processing Record 29 of Set 3 | texarkana
# Processing Record 30 of Set 3 | spencer
# Processing Record 31 of Set 3 | saint-ambroise
# Processing Record 32 of Set 3 | brigantine
# Processing Record 33 of Set 3 | parras
# City not found. Skipping...
# Processing Record 34 of Set 3 | fernie
# Processing Record 35 of Set 3 | charleston
# Processing Record 36 of Set 3 | leesburg
# Processing Record 37 of Set 3 | havelock
# Processing Record 38 of Set 3 | clinton
# Processing Record 39 of Set 3 | la cruz
# Processing Record 40 of Set 3 | el fuerte
# Processing Record 41 of Set 3 | guadalupe y calvo
# Processing Record 42 of Set 3 | virginia beach
# Processing Record 43 of Set 3 | kamsack
# Processing Record 44 of Set 3 | yellowknife
# Processing Record 45 of Set 3 | ures
# Processing Record 46 of Set 3 | ukiah
# Processing Record 47 of Set 3 | enid
# Processing Record 48 of Set 3 | wilmington
# Processing Record 49 of Set 3 | pampa
# Processing Record 0 of Set 4 | houma
# Processing Record 1 of Set 4 | logan
# Processing Record 2 of Set 4 | isabela
# Processing Record 3 of Set 4 | hope
# Processing Record 4 of Set 4 | nuevitas
# Processing Record 5 of Set 4 | torrington
# Processing Record 6 of Set 4 | cape canaveral
# Processing Record 7 of Set 4 | bullhead city
# Processing Record 8 of Set 4 | ketchikan
# Processing Record 9 of Set 4 | rexburg
# Processing Record 10 of Set 4 | great falls
# Processing Record 11 of Set 4 | gallup
# Processing Record 12 of Set 4 | mount pleasant
# Processing Record 13 of Set 4 | muscatine
# Processing Record 14 of Set 4 | port arthur
# Processing Record 15 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 4 | kailua
# Processing Record 17 of Set 4 | front royal
# Processing Record 18 of Set 4 | kingman
# Processing Record 19 of Set 4 | cleveland
# Processing Record 20 of Set 4 | alpena
# Processing Record 21 of Set 4 | tlahualilo
# City not found. Skipping...
# Processing Record 22 of Set 4 | bay city
# Processing Record 23 of Set 4 | burley
# Processing Record 24 of Set 4 | astoria
# Processing Record 25 of Set 4 | ojinaga
# Processing Record 26 of Set 4 | atikokan
# Processing Record 27 of Set 4 | prior lake
# Processing Record 28 of Set 4 | mastic beach
# Processing Record 29 of Set 4 | haines junction
# Processing Record 30 of Set 4 | rupert
# Processing Record 31 of Set 4 | farmington
# Processing Record 32 of Set 4 | cap-haitien
# Processing Record 33 of Set 4 | whitehorse
# Processing Record 34 of Set 4 | price
# Processing Record 35 of Set 4 | boissevain
# Processing Record 36 of Set 4 | vidalia
# Processing Record 37 of Set 4 | panama city
# Processing Record 38 of Set 4 | carlyle
# Processing Record 39 of Set 4 | stayner
# Processing Record 40 of Set 4 | merrill
# Processing Record 41 of Set 4 | matamoros
# Processing Record 42 of Set 4 | hays
# Processing Record 43 of Set 4 | minnedosa
# Processing Record 44 of Set 4 | harwich
# Processing Record 45 of Set 4 | pierre
# Processing Record 46 of Set 4 | show low
# Processing Record 47 of Set 4 | ridgetown
# Processing Record 48 of Set 4 | mankato
# Processing Record 49 of Set 4 | norman wells
# Processing Record 0 of Set 5 | pell city
# Processing Record 1 of Set 5 | rapid valley
# Processing Record 2 of Set 5 | aguada de pasajeros
# Processing Record 3 of Set 5 | sioux lookout
# Processing Record 4 of Set 5 | dzilam gonzalez
# Processing Record 5 of Set 5 | paris
# Processing Record 6 of Set 5 | north platte
# Processing Record 7 of Set 5 | santa cruz del sur
# Processing Record 8 of Set 5 | natchez
# Processing Record 9 of Set 5 | lapeer
# Processing Record 10 of Set 5 | cuetzalan
# Processing Record 11 of Set 5 | swan river
# Processing Record 12 of Set 5 | meadow lake
# Processing Record 13 of Set 5 | sanford
# Processing Record 14 of Set 5 | berlin
# Processing Record 15 of Set 5 | moa
# Processing Record 16 of Set 5 | san felipe
# Processing Record 17 of Set 5 | freeport
# Processing Record 18 of Set 5 | tenabo
# Processing Record 19 of Set 5 | kapaa
# Processing Record 20 of Set 5 | marathon
# Processing Record 21 of Set 5 | huntington
# Processing Record 22 of Set 5 | quincy
# Processing Record 23 of Set 5 | republic
# Processing Record 24 of Set 5 | beaverton
# Processing Record 25 of Set 5 | cortez
# Processing Record 26 of Set 5 | cosala
# Processing Record 27 of Set 5 | rosarito
# Processing Record 28 of Set 5 | bernalillo
# Processing Record 29 of Set 5 | brooks
# Processing Record 30 of Set 5 | sidney
# Processing Record 31 of Set 5 | panaba
# Processing Record 32 of Set 5 | el salto
# Processing Record 33 of Set 5 | mount vernon
# Processing Record 34 of Set 5 | fallon
# Processing Record 35 of Set 5 | guantanamo
# Processing Record 36 of Set 5 | green river
# Processing Record 37 of Set 5 | sagua la grande
# Processing Record 38 of Set 5 | tamiahua
# Processing Record 39 of Set 5 | cozumel
# Processing Record 40 of Set 5 | maryville
# Processing Record 41 of Set 5 | berea
# Processing Record 42 of Set 5 | mapimi
# Processing Record 43 of Set 5 | bolivar
# Processing Record 44 of Set 5 | socorro
# Processing Record 45 of Set 5 | hurricane
# Processing Record 46 of Set 5 | woodward
# Processing Record 47 of Set 5 | pueblo
# Processing Record 48 of Set 5 | north bend
# Processing Record 49 of Set 5 | sheridan
# Processing Record 0 of Set 6 | beatrice
# Processing Record 1 of Set 6 | haslett
# Processing Record 2 of Set 6 | lake charles
# Processing Record 3 of Set 6 | vanderhoof
# Processing Record 4 of Set 6 | houston
# Processing Record 5 of Set 6 | athabasca
# Processing Record 6 of Set 6 | x-can
# City not found. Skipping...
# Processing Record 7 of Set 6 | anderson
# Processing Record 8 of Set 6 | unity
# Processing Record 9 of Set 6 | asbestos
# Processing Record 10 of Set 6 | battle creek
# Processing Record 11 of Set 6 | east wenatchee bench
# Processing Record 12 of Set 6 | maniwaki
# Processing Record 13 of Set 6 | winslow
# Processing Record 14 of Set 6 | key west
# Processing Record 15 of Set 6 | murfreesboro
# Processing Record 16 of Set 6 | itzincab
# City not found. Skipping...
# Processing Record 17 of Set 6 | lac du bonnet
# Processing Record 18 of Set 6 | alice
# Processing Record 19 of Set 6 | glencoe
# Processing Record 20 of Set 6 | souris
# Processing Record 21 of Set 6 | whitefish
# Processing Record 22 of Set 6 | glendive
# Processing Record 23 of Set 6 | pascagoula
# Processing Record 24 of Set 6 | obregon
# Processing Record 25 of Set 6 | west wendover
# Processing Record 26 of Set 6 | alliston
# Processing Record 27 of Set 6 | artesia
# Processing Record 28 of Set 6 | brainerd
# Processing Record 29 of Set 6 | kenora
# Processing Record 30 of Set 6 | duluth
# Processing Record 31 of Set 6 | les escoumins
# Processing Record 32 of Set 6 | glenwood springs
# Processing Record 33 of Set 6 | canitas
# City not found. Skipping...
# Processing Record 34 of Set 6 | tooele
# Processing Record 35 of Set 6 | prince rupert
# Processing Record 36 of Set 6 | lanigan
# Processing Record 37 of Set 6 | palau
# Processing Record 38 of Set 6 | la grande
# Processing Record 39 of Set 6 | shaunavon
# Processing Record 40 of Set 6 | mobile
# Processing Record 41 of Set 6 | fountain hills
# Processing Record 42 of Set 6 | lacey
# Processing Record 43 of Set 6 | moose factory
# Processing Record 44 of Set 6 | west bay
# Processing Record 45 of Set 6 | hailey
# Processing Record 46 of Set 6 | progreso
# Processing Record 47 of Set 6 | melfort
# Processing Record 48 of Set 6 | eloy
# Processing Record 49 of Set 6 | kitimat
# Processing Record 0 of Set 7 | saint george
# Processing Record 1 of Set 7 | topeka
# Processing Record 2 of Set 7 | okmulgee
# Processing Record 3 of Set 7 | marshfield
# Processing Record 4 of Set 7 | poplar bluff
# Processing Record 5 of Set 7 | redmond
# Processing Record 6 of Set 7 | north battleford
# Processing Record 7 of Set 7 | jackson
# Processing Record 8 of Set 7 | sept-iles
# Processing Record 9 of Set 7 | englehart
# Processing Record 10 of Set 7 | lewistown
# Processing Record 11 of Set 7 | lake city
# Processing Record 12 of Set 7 | elko
# Processing Record 13 of Set 7 | casas grandes
# Processing Record 14 of Set 7 | cloquet
# Processing Record 15 of Set 7 | bainbridge
# Processing Record 16 of Set 7 | mitchell
# Processing Record 17 of Set 7 | miles city
# Processing Record 18 of Set 7 | sahuaripa
# Processing Record 19 of Set 7 | great bend
# Processing Record 20 of Set 7 | beloeil
# Processing Record 21 of Set 7 | sault sainte marie
# Processing Record 22 of Set 7 | tucumcari
# Processing Record 23 of Set 7 | streator
# Processing Record 24 of Set 7 | black forest
# Processing Record 25 of Set 7 | senneterre
# Processing Record 26 of Set 7 | columbia
# Processing Record 27 of Set 7 | indian harbour beach
# Processing Record 28 of Set 7 | brownsville
# Processing Record 29 of Set 7 | oxbow
# Processing Record 30 of Set 7 | baie-comeau
# Processing Record 31 of Set 7 | new ulm
# Processing Record 32 of Set 7 | normandin
# Processing Record 33 of Set 7 | cedar city
# Processing Record 34 of Set 7 | rivers
# Processing Record 35 of Set 7 | monroe
# Processing Record 36 of Set 7 | kingsville
# Processing Record 37 of Set 7 | yarmouth
# Processing Record 38 of Set 7 | lamar
# Processing Record 39 of Set 7 | santa catarina de tepehuanes
# Processing Record 40 of Set 7 | morgan city
# Processing Record 41 of Set 7 | oxford
# Processing Record 42 of Set 7 | sturgis
# Processing Record 43 of Set 7 | baraboo
# Processing Record 44 of Set 7 | centerville
# Processing Record 45 of Set 7 | medicine hat
# Processing Record 46 of Set 7 | chapleau
# Processing Record 47 of Set 7 | salina
# Processing Record 48 of Set 7 | rapid city
# Processing Record 49 of Set 7 | langenburg
# Processing Record 0 of Set 8 | macomb
# Processing Record 1 of Set 8 | ada
# Processing Record 2 of Set 8 | praxedis guerrero
# Processing Record 3 of Set 8 | nanaimo
# Processing Record 4 of Set 8 | bathurst
# Processing Record 5 of Set 8 | homer
# Processing Record 6 of Set 8 | valley city
# Processing Record 7 of Set 8 | casper
# Processing Record 8 of Set 8 | acaponeta
# Processing Record 9 of Set 8 | merritt island
# Processing Record 10 of Set 8 | nelson
# Processing Record 11 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 12 of Set 8 | cancun
# Processing Record 13 of Set 8 | grants
# Processing Record 14 of Set 8 | alexandria
# Processing Record 15 of Set 8 | nakusp
# Processing Record 16 of Set 8 | little current
# Processing Record 17 of Set 8 | irricana
# Processing Record 18 of Set 8 | vega de alatorre
# Processing Record 19 of Set 8 | sedro-woolley
# Processing Record 20 of Set 8 | killam
# Processing Record 21 of Set 8 | ocampo
# Processing Record 22 of Set 8 | carbondale
# Processing Record 23 of Set 8 | nuevo progreso
# Processing Record 24 of Set 8 | tahlequah
# Processing Record 25 of Set 8 | klamath falls
# Processing Record 26 of Set 8 | barstow
# Processing Record 27 of Set 8 | atotonilco el grande
# Processing Record 28 of Set 8 | moundsville
# Processing Record 29 of Set 8 | avenal
# Processing Record 30 of Set 8 | allende
# Processing Record 31 of Set 8 | gibara
# Processing Record 32 of Set 8 | numaran
# Processing Record 33 of Set 8 | hinton
# Processing Record 34 of Set 8 | fremont
# Processing Record 35 of Set 8 | raton
# Processing Record 36 of Set 8 | galveston
# Processing Record 37 of Set 8 | plainview
# Processing Record 38 of Set 8 | weiser
# Processing Record 39 of Set 8 | la palma
# Processing Record 40 of Set 8 | meridian
# Processing Record 41 of Set 8 | columbus
# Processing Record 42 of Set 8 | truckee
# Processing Record 43 of Set 8 | douglas
# Processing Record 44 of Set 8 | rockport
# Processing Record 45 of Set 8 | smoky lake
# Processing Record 46 of Set 8 | golden
# Processing Record 47 of Set 8 | devils lake
# Processing Record 48 of Set 8 | copperas cove
# Processing Record 49 of Set 8 | estelle
# Processing Record 0 of Set 9 | wembley
# Processing Record 1 of Set 9 | belle fourche
# Processing Record 2 of Set 9 | washougal
# Processing Record 3 of Set 9 | beckley
# Processing Record 4 of Set 9 | dryden
# Processing Record 5 of Set 9 | clarksburg
# Processing Record 6 of Set 9 | howard
# Processing Record 7 of Set 9 | bend
# Processing Record 8 of Set 9 | centralia
# Processing Record 9 of Set 9 | winnemucca
# Processing Record 10 of Set 9 | livingston
# Processing Record 11 of Set 9 | eston
# Processing Record 12 of Set 9 | waycross
# Processing Record 13 of Set 9 | pine bluff
# Processing Record 14 of Set 9 | calvillo
# Processing Record 15 of Set 9 | bemidji
# Processing Record 16 of Set 9 | grand rapids
# Processing Record 17 of Set 9 | manchester
# Processing Record 18 of Set 9 | richfield
# Processing Record 19 of Set 9 | camalu
# Processing Record 20 of Set 9 | blacksburg
# Processing Record 21 of Set 9 | west lorne
# Processing Record 22 of Set 9 | chowchilla
# Processing Record 23 of Set 9 | tuskegee
# Processing Record 24 of Set 9 | bozeman
# Processing Record 25 of Set 9 | newport
# Processing Record 26 of Set 9 | placerville
# Processing Record 27 of Set 9 | seybaplaya
# Processing Record 28 of Set 9 | saint peter
# Processing Record 29 of Set 9 | uniontown
# Processing Record 30 of Set 9 | cheyenne
# Processing Record 31 of Set 9 | dawson creek
# Processing Record 32 of Set 9 | gimli
# Processing Record 33 of Set 9 | menomonie
# Processing Record 34 of Set 9 | beaverlodge
# Processing Record 35 of Set 9 | los arabos
# Processing Record 36 of Set 9 | moss point
# Processing Record 37 of Set 9 | canton
# Processing Record 38 of Set 9 | traverse city
# Processing Record 39 of Set 9 | santa cruz del norte
# Processing Record 40 of Set 9 | bardstown
# Processing Record 41 of Set 9 | badiraguato
# Processing Record 42 of Set 9 | godfrey
# Processing Record 43 of Set 9 | glasgow
# Processing Record 44 of Set 9 | naco
# Processing Record 45 of Set 9 | fredericksburg
# Processing Record 46 of Set 9 | kenai
# Processing Record 47 of Set 9 | fenton
# Processing Record 48 of Set 9 | mill valley
# Processing Record 49 of Set 9 | casa grande
# Processing Record 0 of Set 10 | esmeralda
# Processing Record 1 of Set 10 | ciudad valles
# Processing Record 2 of Set 10 | port hope
# Processing Record 3 of Set 10 | bismarck
# Processing Record 4 of Set 10 | flagstaff
# Processing Record 5 of Set 10 | jasper
# Processing Record 6 of Set 10 | princeton
# Processing Record 7 of Set 10 | russellville
# Processing Record 8 of Set 10 | camp verde
# Processing Record 9 of Set 10 | callaway
# Processing Record 10 of Set 10 | new bern
# Processing Record 11 of Set 10 | grinnell
# Processing Record 12 of Set 10 | humboldt
# Processing Record 13 of Set 10 | knoxville
# Processing Record 14 of Set 10 | belvidere
# Processing Record 15 of Set 10 | espanola
# Processing Record 16 of Set 10 | tallahassee
# Processing Record 17 of Set 10 | cocorit
# Processing Record 18 of Set 10 | neepawa
# Processing Record 19 of Set 10 | brandon
# Processing Record 20 of Set 10 | sylacauga
# Processing Record 21 of Set 10 | golden gate
# Processing Record 22 of Set 10 | skowhegan
# Processing Record 23 of Set 10 | monte cristi
# City not found. Skipping...
# Processing Record 24 of Set 10 | uvalde
# Processing Record 25 of Set 10 | danville
# Processing Record 26 of Set 10 | clarence town
# Processing Record 27 of Set 10 | kuna
# Processing Record 28 of Set 10 | lexington
# Processing Record 29 of Set 10 | brenham
# Processing Record 30 of Set 10 | riverton
# Processing Record 31 of Set 10 | saraland
# Processing Record 32 of Set 10 | assiniboia
# Processing Record 33 of Set 10 | quila
# Processing Record 34 of Set 10 | culpeper
# Processing Record 35 of Set 10 | claremore
# Processing Record 36 of Set 10 | silver city
# Processing Record 37 of Set 10 | dauphin
# Processing Record 38 of Set 10 | indianola
# Processing Record 39 of Set 10 | kerrville
# Processing Record 40 of Set 10 | rancho palos verdes
# Processing Record 41 of Set 10 | pinar del rio
# Processing Record 42 of Set 10 | las vegas
# Processing Record 43 of Set 10 | puerto penasco
# Processing Record 44 of Set 10 | forestville
# Processing Record 45 of Set 10 | taylorville
# Processing Record 46 of Set 10 | dublin
# Processing Record 47 of Set 10 | parry sound
# Processing Record 48 of Set 10 | deming
# Processing Record 49 of Set 10 | villa union
# Processing Record 0 of Set 11 | drayton valley
# Processing Record 1 of Set 11 | north auburn
# Processing Record 2 of Set 11 | saint simons
# Processing Record 3 of Set 11 | asheville
# Processing Record 4 of Set 11 | vicksburg
# Processing Record 5 of Set 11 | camargo
# Processing Record 6 of Set 11 | pontiac
# Processing Record 7 of Set 11 | west odessa
# Processing Record 8 of Set 11 | chalmette
# Processing Record 9 of Set 11 | notre-dame-du-lac
# Processing Record 10 of Set 11 | fredericton
# Processing Record 11 of Set 11 | santa engracia
# Processing Record 12 of Set 11 | saucillo
# Processing Record 13 of Set 11 | belgrade
# Processing Record 14 of Set 11 | nanton
# Processing Record 15 of Set 11 | snyder
# Processing Record 16 of Set 11 | myrtle beach
# Processing Record 17 of Set 11 | marshall
# Processing Record 18 of Set 11 | bristol
# Processing Record 19 of Set 11 | north myrtle beach
# Processing Record 20 of Set 11 | lamesa
# Processing Record 21 of Set 11 | hermosillo
# Processing Record 22 of Set 11 | plover
# Processing Record 23 of Set 11 | maneadero
# Processing Record 24 of Set 11 | bucerias
# Processing Record 25 of Set 11 | sechelt
# Processing Record 26 of Set 11 | minden
# Processing Record 27 of Set 11 | hilton head island
# Processing Record 28 of Set 11 | cardston
# Processing Record 29 of Set 11 | sandpoint
# Processing Record 30 of Set 11 | saint leonard
# Processing Record 31 of Set 11 | ashland
# Processing Record 32 of Set 11 | chickasha
# Processing Record 33 of Set 11 | emmett
# Processing Record 34 of Set 11 | sain alto
# Processing Record 35 of Set 11 | hauterive
# Processing Record 36 of Set 11 | abilene
# Processing Record 37 of Set 11 | harrisburg
# Processing Record 38 of Set 11 | muzquiz
# City not found. Skipping...
# Processing Record 39 of Set 11 | blackfoot
# Processing Record 40 of Set 11 | guane
# Processing Record 41 of Set 11 | nadadores
# Processing Record 42 of Set 11 | teacapan
# Processing Record 43 of Set 11 | oswego
# Processing Record 44 of Set 11 | carroll
# Processing Record 45 of Set 11 | creel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_pd = pd.DataFrame(city_data)
city_data_pd.count()
# Out:
# City          533
# Lat           533
# Lng           533
# Max Temp      533
# Humidity      533
# Cloudiness    533
# Wind Speed    533
# Country       533
# Date          533
# dtype: int64

# %%
# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City")

# %%
city_data_pd.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   iqaluit  63.7506  -68.5145     -13.0        58          75       18.41
# 1     craig  40.5153 -107.5464      35.6        75          90       18.41
# 2  coos bay  43.3665 -124.2179      44.6        87          90       10.36
# 3      hilo  19.7297 -155.0900      75.0        78          20        8.43
# 4   timmins  48.4669  -81.3331      14.0        44          20       14.97
#
#   Country        Date
# 0      CA  1615751499
# 1      US  1615751499
# 2      US  1615751499
# 3      US  1615751234
# 4      CA  1615751500

# %%
america_city = city_data_pd[(city_data_pd["Country"]=="US")]
america_city
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1         craig  40.5153 -107.5464     35.60        75          90
# 2      coos bay  43.3665 -124.2179     44.60        87          90
# 3          hilo  19.7297 -155.0900     75.00        78          20
# 5        palmer  42.1584  -72.3287     42.80        39          40
# 6         sitka  57.0531 -135.3300     28.40        59           1
# ..          ...      ...       ...       ...       ...         ...
# 524     abilene  32.4487  -99.7331     70.00        22           1
# 525  harrisburg  40.2737  -76.8844     59.00        15           1
# 526   blackfoot  43.1905 -112.3450     50.00        32           1
# 530      oswego  43.4501  -76.1497     33.01        51         100
# 531     carroll  39.5501  -77.0164     60.80        20           1
#
#      Wind Speed Country        Date
# 1         18.41      US  1615751499
# 2         10.36      US  1615751499
# 3          8.43      US  1615751234
# 5         29.93      US  1615751500
# 6         12.66      US  1615751500
# ..          ...     ...         ...
# 524       21.85      US  1615751639
# 525       21.85      US  1615751597
# 526       11.50      US  1615751640
# 530       19.57      US  1615751641
# 531       21.85      US  1615751546
#
# [309 rows x 9 columns]

# %%
tornado_df2=tornado_df.copy()

# %%
tornado_df["City"] = tornado_df["City"].str.lower()
tornado_df
# Out:
#                City STATE_ABBR        Date EVENT_TYPE TOR_F_SCALE  \
# 0    truttneys lndg         NC   11/1/2019    Tornado         EF0
# 1          waveland         FL   11/5/2019    Tornado         EF0
# 2          prichard         AL   11/7/2019    Tornado         EF0
# 3            baskin         LA  11/26/2019    Tornado         EF2
# 4             mahan         LA  11/26/2019    Tornado         EF1
# ..              ...        ...         ...        ...         ...
# 495          lamont         GA   4/13/2020    Tornado         EF0
# 496         red oak         GA   4/13/2020    Tornado         EF0
# 497         collier         GA   4/13/2020    Tornado         EF3
# 498    roberts xrds         GA   4/13/2020    Tornado         EF0
# 499           raoul         GA   4/13/2020    Tornado         EF1
#
#      DEATHS_DIRECT      Lat      Lng          END_LOCATION
# 0                0  34.7394 -77.1094        TRUTTNEYS LNDG
# 1                0  27.2140 -80.1729              WAVELAND
# 2                0  30.7248 -88.0548              PRICHARD
# 3                1  32.2351 -91.7783                BASKIN
# 4                0  32.9017 -93.0423                 MAHAN
# ..             ...      ...      ...                   ...
# 495              0  32.9896 -84.1225                LAMONT
# 496              0  33.6288 -84.5263               RED OAK
# 497              0  33.0298 -84.0330        BRIGHTON MILLS
# 498              0  33.4560 -83.6449          ROBERTS XRDS
# 499              0  34.4590 -83.6350  CORNLIA HBRSHAM ARPT
#
# [500 rows x 9 columns]

# %%
america_city.City = america_city.City.astype(str)
tornado_df.City = tornado_df.City.astype(str)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
concat_df=pd.concat([tornado_df.set_index("City"), america_city.set_index("City")], join="outer")
concat_df
# Out:
#                STATE_ABBR        Date EVENT_TYPE TOR_F_SCALE  DEATHS_DIRECT  \
# City
# truttneys lndg         NC   11/1/2019    Tornado         EF0            0.0
# waveland               FL   11/5/2019    Tornado         EF0            0.0
# prichard               AL   11/7/2019    Tornado         EF0            0.0
# baskin                 LA  11/26/2019    Tornado         EF2            1.0
# mahan                  LA  11/26/2019    Tornado         EF1            0.0
# ...                   ...         ...        ...         ...            ...
# abilene               NaN  1615751639        NaN         NaN            NaN
# harrisburg            NaN  1615751597        NaN         NaN            NaN
# blackfoot             NaN  1615751640        NaN         NaN            NaN
# oswego                NaN  1615751641        NaN         NaN            NaN
# carroll               NaN  1615751546        NaN         NaN            NaN
#
#                     Lat       Lng    END_LOCATION  Max Temp  Humidity  \
# City
# truttneys lndg  34.7394  -77.1094  TRUTTNEYS LNDG       NaN       NaN
# waveland        27.2140  -80.1729        WAVELAND       NaN       NaN
# prichard        30.7248  -88.0548        PRICHARD       NaN       NaN
# baskin          32.2351  -91.7783          BASKIN       NaN       NaN
# mahan           32.9017  -93.0423           MAHAN       NaN       NaN
# ...                 ...       ...             ...       ...       ...
# abilene         32.4487  -99.7331             NaN     70.00      22.0
# harrisburg      40.2737  -76.8844             NaN     59.00      15.0
# blackfoot       43.1905 -112.3450             NaN     50.00      32.0
# oswego          43.4501  -76.1497             NaN     33.01      51.0
# carroll         39.5501  -77.0164             NaN     60.80      20.0
#
#                 Cloudiness  Wind Speed Country
# City
# truttneys lndg         NaN         NaN     NaN
# waveland               NaN         NaN     NaN
# prichard               NaN         NaN     NaN
# baskin                 NaN         NaN     NaN
# mahan                  NaN         NaN     NaN
# ...                    ...         ...     ...
# abilene                1.0       21.85      US
# harrisburg             1.0       21.85      US
# blackfoot              1.0       11.50      US
# oswego               100.0       19.57      US
# carroll                1.0       21.85      US
#
# [809 rows x 13 columns]

# %%
concat_df["Date"]=(pd.to_datetime(concat_df["Date"]))
concat_df
# Out:
#                STATE_ABBR                          Date EVENT_TYPE  \
# City
# truttneys lndg         NC 2019-11-01 00:00:00.000000000    Tornado
# waveland               FL 2019-11-05 00:00:00.000000000    Tornado
# prichard               AL 2019-11-07 00:00:00.000000000    Tornado
# baskin                 LA 2019-11-26 00:00:00.000000000    Tornado
# mahan                  LA 2019-11-26 00:00:00.000000000    Tornado
# ...                   ...                           ...        ...
# abilene               NaN 1970-01-01 00:00:01.615751639        NaN
# harrisburg            NaN 1970-01-01 00:00:01.615751597        NaN
# blackfoot             NaN 1970-01-01 00:00:01.615751640        NaN
# oswego                NaN 1970-01-01 00:00:01.615751641        NaN
# carroll               NaN 1970-01-01 00:00:01.615751546        NaN
#
#                TOR_F_SCALE  DEATHS_DIRECT      Lat       Lng    END_LOCATION  \
# City
# truttneys lndg         EF0            0.0  34.7394  -77.1094  TRUTTNEYS LNDG
# waveland               EF0            0.0  27.2140  -80.1729        WAVELAND
# prichard               EF0            0.0  30.7248  -88.0548        PRICHARD
# baskin                 EF2            1.0  32.2351  -91.7783          BASKIN
# mahan                  EF1            0.0  32.9017  -93.0423           MAHAN
# ...                    ...            ...      ...       ...             ...
# abilene                NaN            NaN  32.4487  -99.7331             NaN
# harrisburg             NaN            NaN  40.2737  -76.8844             NaN
# blackfoot              NaN            NaN  43.1905 -112.3450             NaN
# oswego                 NaN            NaN  43.4501  -76.1497             NaN
# carroll                NaN            NaN  39.5501  -77.0164             NaN
#
#                 Max Temp  Humidity  Cloudiness  Wind Speed Country
# City
# truttneys lndg       NaN       NaN         NaN         NaN     NaN
# waveland             NaN       NaN         NaN         NaN     NaN
# prichard             NaN       NaN         NaN         NaN     NaN
# baskin               NaN       NaN         NaN         NaN     NaN
# mahan                NaN       NaN         NaN         NaN     NaN
# ...                  ...       ...         ...         ...     ...
# abilene            70.00      22.0         1.0       21.85      US
# harrisburg         59.00      15.0         1.0       21.85      US
# blackfoot          50.00      32.0         1.0       11.50      US
# oswego             33.01      51.0       100.0       19.57      US
# carroll            60.80      20.0         1.0       21.85      US
#
# [809 rows x 13 columns]

# %%
concat_df["Date"] = concat_df["Date"].map(lambda ts: ts.strftime("%m-%d-%Y"))
concat_df
# Out:
#                STATE_ABBR        Date EVENT_TYPE TOR_F_SCALE  DEATHS_DIRECT  \
# City
# truttneys lndg         NC  11-01-2019    Tornado         EF0            0.0
# waveland               FL  11-05-2019    Tornado         EF0            0.0
# prichard               AL  11-07-2019    Tornado         EF0            0.0
# baskin                 LA  11-26-2019    Tornado         EF2            1.0
# mahan                  LA  11-26-2019    Tornado         EF1            0.0
# ...                   ...         ...        ...         ...            ...
# abilene               NaN  01-01-1970        NaN         NaN            NaN
# harrisburg            NaN  01-01-1970        NaN         NaN            NaN
# blackfoot             NaN  01-01-1970        NaN         NaN            NaN
# oswego                NaN  01-01-1970        NaN         NaN            NaN
# carroll               NaN  01-01-1970        NaN         NaN            NaN
#
#                     Lat       Lng    END_LOCATION  Max Temp  Humidity  \
# City
# truttneys lndg  34.7394  -77.1094  TRUTTNEYS LNDG       NaN       NaN
# waveland        27.2140  -80.1729        WAVELAND       NaN       NaN
# prichard        30.7248  -88.0548        PRICHARD       NaN       NaN
# baskin          32.2351  -91.7783          BASKIN       NaN       NaN
# mahan           32.9017  -93.0423           MAHAN       NaN       NaN
# ...                 ...       ...             ...       ...       ...
# abilene         32.4487  -99.7331             NaN     70.00      22.0
# harrisburg      40.2737  -76.8844             NaN     59.00      15.0
# blackfoot       43.1905 -112.3450             NaN     50.00      32.0
# oswego          43.4501  -76.1497             NaN     33.01      51.0
# carroll         39.5501  -77.0164             NaN     60.80      20.0
#
#                 Cloudiness  Wind Speed Country
# City
# truttneys lndg         NaN         NaN     NaN
# waveland               NaN         NaN     NaN
# prichard               NaN         NaN     NaN
# baskin                 NaN         NaN     NaN
# mahan                  NaN         NaN     NaN
# ...                    ...         ...     ...
# abilene                1.0       21.85      US
# harrisburg             1.0       21.85      US
# blackfoot              1.0       11.50      US
# oswego               100.0       19.57      US
# carroll                1.0       21.85      US
#
# [809 rows x 13 columns]

# %%
filteredtime_df = concat_df.loc[(concat_df["Date"] >= "11-01-2019")]
filteredtime_df
# Out:
#                STATE_ABBR        Date EVENT_TYPE TOR_F_SCALE  DEATHS_DIRECT  \
# City
# truttneys lndg         NC  11-01-2019    Tornado         EF0            0.0
# waveland               FL  11-05-2019    Tornado         EF0            0.0
# prichard               AL  11-07-2019    Tornado         EF0            0.0
# baskin                 LA  11-26-2019    Tornado         EF2            1.0
# mahan                  LA  11-26-2019    Tornado         EF1            0.0
# ...                   ...         ...        ...         ...            ...
# ethel                  MS  12-29-2019    Tornado         EF1            0.0
# weir                   MS  12-29-2019    Tornado         EF1            0.0
# adaton                 MS  12-29-2019    Tornado         EF0            0.0
# stratton               MS  12-29-2019    Tornado         EF1            0.0
# lawngate               AL  12-29-2019    Tornado         EF0            0.0
#
#                     Lat      Lng          END_LOCATION  Max Temp  Humidity  \
# City
# truttneys lndg  34.7394 -77.1094        TRUTTNEYS LNDG       NaN       NaN
# waveland        27.2140 -80.1729              WAVELAND       NaN       NaN
# prichard        30.7248 -88.0548              PRICHARD       NaN       NaN
# baskin          32.2351 -91.7783                BASKIN       NaN       NaN
# mahan           32.9017 -93.0423                 MAHAN       NaN       NaN
# ...                 ...      ...                   ...       ...       ...
# ethel           33.1628 -89.4323               MC COOL       NaN       NaN
# weir            33.2598 -89.2778  ACKERMAN CHOCTAW ARP       NaN       NaN
# adaton          33.4720 -89.0315                ADATON       NaN       NaN
# stratton        32.5268 -89.1628                 UNION       NaN       NaN
# lawngate        34.7541 -87.0777                ATHENS       NaN       NaN
#
#                 Cloudiness  Wind Speed Country
# City
# truttneys lndg         NaN         NaN     NaN
# waveland               NaN         NaN     NaN
# prichard               NaN         NaN     NaN
# baskin                 NaN         NaN     NaN
# mahan                  NaN         NaN     NaN
# ...                    ...         ...     ...
# ethel                  NaN         NaN     NaN
# weir                   NaN         NaN     NaN
# adaton                 NaN         NaN     NaN
# stratton               NaN         NaN     NaN
# lawngate               NaN         NaN     NaN
#
# [95 rows x 13 columns]

# %%
Lat = filteredtime_df["Lat"]
max_temps = filteredtime_df["Max Temp"]
humidity = filteredtime_df["Humidity"]
cloudiness = filteredtime_df["Cloudiness"]
wind_speed = filteredtime_df["Wind Speed"]
TOR_F_SCALE = filteredtime_df["TOR_F_SCALE"]
# Export the City_Data into a csv
filteredtime_df.to_csv(output_data_file, index_label="City")

# %%
plt.scatter(Lat, TOR_F_SCALE, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title(f"City Latitude v Tornado F Scale")
plt.xlabel("Latitude")
plt.ylabel("Tornado F Scale")
plt.grid(True)

plt.savefig("data/Fig1.png")
plt.show()
